# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series, DataFrame

# %% [markdown]
# ### 直方图

# %%
s = Series(np.random.randn(1000))

# %%
plt.hist(s,rwidth=0.8, color='r', bins=20)
# Out:
# (array([  7.,  11.,   9.,  27.,  44.,  61.,  90., 116., 133., 116., 116.,
#         100.,  64.,  47.,  33.,  14.,   5.,   5.,   0.,   2.]),
#  array([-2.76509713, -2.45355229, -2.14200745, -1.83046262, -1.51891778,
#         -1.20737294, -0.89582811, -0.58428327, -0.27273843,  0.0388064 ,
#          0.35035124,  0.66189608,  0.97344092,  1.28498575,  1.59653059,
#          1.90807543,  2.21962026,  2.5311651 ,  2.84270994,  3.15425477,
#          3.46579961]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# ### 密度图

# %%
s.plot(kind='kde')
